# %% [markdown]
# # **K-Means CLustering**

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.metrics import accuracy_score

# %%
X = np.array([[1,2], [5,8], [1.5,1.8], [8,8], [6,7], [9,11]])

print(X)
# Out:
# [[ 1.   2. ]
#  [ 5.   8. ]
#  [ 1.5  1.8]
#  [ 8.   8. ]
#  [ 6.   7. ]
#  [ 9.  11. ]]

# %%
labelX = np.array([0,0,1,0,1,1])
print(labelX)
# Out:
# [0 0 1 0 1 1]

# %%
k_means = KMeans(n_clusters=2)

k_means.fit(X)
# Out:
# KMeans(n_clusters=2)

# %%
centroids = k_means.cluster_centers_
labels = k_means.labels_

print('Labels       :', labels)
print('Centro Ids   :', centroids)
# Out:
# Labels       : [1 0 1 0 0 0]
# Centro Ids   : [[7.   8.5 ]
#  [1.25 1.9 ]]

# %%
colors = ['g.', 'r.', 'c.', 'y.']

for i in range(len(X)):
    print('Coordinate   :', X[i])
    print('Labels       :', labels[i])
    plt.plot(X[i] [0], X[i] [1], colors[labels[i]], markersize = 10)
    plt.scatter(centroids[:, 0], centroids[:,1], marker = 'X', s=150, linewidths=5, zorder=10)

plt.show()

prediction = k_means.predict([[5,6]])

print('Predictions  :', prediction)

print(k_means.predict(X))
print(labelX)
# Out:
# Coordinate   : [1. 2.]
# Labels       : 1
# Coordinate   : [5. 8.]
# Labels       : 0
# Coordinate   : [1.5 1.8]
# Labels       : 1
# Coordinate   : [8. 8.]
# Labels       : 0
# Coordinate   : [6. 7.]
# Labels       : 0
# Coordinate   : [ 9. 11.]
# Labels       : 0
# Predictions  : [0]
# [1 0 1 0 0 0]
# [0 0 1 0 1 1]
