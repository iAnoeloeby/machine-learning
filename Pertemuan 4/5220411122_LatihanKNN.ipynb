# %%
import pandas as pd
dataFrame = pd.read_csv('BankChurn.csv')
dataFrame
# Out:
# /tmp/ipykernel_24722/694242059.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd
#             id  CustomerId         Surname  CreditScore Geography  Gender  \
# 0            0    15674932  Okwudilichukwu          668    France    Male
# 1            1    15749177   Okwudiliolisa          627    France    Male
# 2            2    15694510           Hsueh          678    France    Male
# 3            3    15741417             Kao          581    France    Male
# 4            4    15766172       Chiemenam          716     Spain    Male
# ...

# %%
dataSample = dataFrame.sample(10000)
dataSample
# Out:
#             id  CustomerId    Surname  CreditScore Geography  Gender   Age  \
# 121137  121137    15658852  Degtyarev          850   Germany    Male  38.0
# 118080  118080    15705879   Padovesi          706    France  Female  32.0
# 49027    49027    15585067  Dominguez          593     Spain  Female  33.0
# 81501    81501    15638646       Chin          678   Germany  Female  50.0
# 65266    65266    15794566     Ch'ang          681   Germany  Female  42.0
# ...        ...         ...        ...          ...       ...     ...   ...
# 112166  112166    15659234     Ozioma          689   Germany  Female  47.0
# 14428    14428    15721835   Biryukov          624    France    Male  33.0
# 38387    38387    15811762   Nwabugwu          632    France    Male  45.0
# 153283  153283    15761775       Zito          732    France    Male  34.0
# 4184      4184    15690670    Fanucci          640     Spain    Male  28.0
#
# ...

# %%
print('Ukuran Data: ', dataSample.shape)
# Out:
# Ukuran Data:  (10000, 14)

# %%
# dataSample.columns

# %%
feature_names = dataSample.columns[:-1]
target_names = 'Exited'

features = dataSample[feature_names]
target = dataSample[target_names]

print('Feature Names :', features)
print('Target Names :', target)
# Out:
# Feature Names :             id  CustomerId    Surname  CreditScore Geography  Gender   Age  \
# 121137  121137    15658852  Degtyarev          850   Germany    Male  38.0
# 118080  118080    15705879   Padovesi          706    France  Female  32.0
# 49027    49027    15585067  Dominguez          593     Spain  Female  33.0
# 81501    81501    15638646       Chin          678   Germany  Female  50.0
# 65266    65266    15794566     Ch'ang          681   Germany  Female  42.0
# ...        ...         ...        ...          ...       ...     ...   ...
# 112166  112166    15659234     Ozioma          689   Germany  Female  47.0
# 14428    14428    15721835   Biryukov          624    France    Male  33.0
# 38387    38387    15811762   Nwabugwu          632    France    Male  45.0
# 153283  153283    15761775       Zito          732    France    Male  34.0
# 4184      4184    15690670    Fanucci          640     Spain    Male  28.0
#
# ...

# %%
from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()

dataSample['Surname']   = label_encoder.fit_transform(dataSample['Surname'])
dataSample['Geography'] = label_encoder.fit_transform(dataSample['Geography'])
dataSample['Gender']    = label_encoder.fit_transform(dataSample['Gender'])

dataSample
# Out:
#             id  CustomerId  Surname  CreditScore  Geography  Gender   Age  \
# 121137  121137    15658852      349          850          1       1  38.0
# 118080  118080    15705879     1090          706          0       0  32.0
# 49027    49027    15585067      366          593          2       0  33.0
# 81501    81501    15638646      255          678          1       0  50.0
# 65266    65266    15794566      200          681          1       0  42.0
# ...        ...         ...      ...          ...        ...     ...   ...
# 112166  112166    15659234     1085          689          1       0  47.0
# 14428    14428    15721835      117          624          0       1  33.0
# 38387    38387    15811762      990          632          0       1  45.0
# 153283  153283    15761775     1462          732          0       1  34.0
# 4184      4184    15690670      426          640          2       1  28.0
#
#         Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
X = dataSample.drop('Exited', axis=1)
Y = dataSample['Exited']

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.2)

# %%
print(x_train.shape)
print(x_test.shape)
# Out:
# (8000, 13)
# (2000, 13)

# %%
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(x_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
y_predict = knn.predict(x_test)

# %%
from sklearn import metrics
print('Accuracy of K-NN Model: ', metrics.accuracy_score(y_test, y_predict))
# Out:
# Accuracy of K-NN Model:  0.7405

# %%
sample = [[289453, 15663487, 618, 659, 1, 1, 42.0, 1, 125901.52, 2, 1.0, 0.0, 93081.91]]
predictions = knn.predict(sample)
# pred_species = [df.target_names[p] for p in preds]
print("Hasil Prediksi Sampel Data : ", predictions)
# Out:
# Hasil Prediksi Sampel Data :  [0]
# /home/codespace/.local/lib/python3.10/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(
