# %%
import pandas as pd
dataFrame = pd.read_csv('interstellar_travel.csv')
dataFrame
# Out:
# /tmp/ipykernel_10159/1046938196.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd
#         Age  Gender      Occupation Travel Class            Destination  \
# 0        14  Female        Colonist     Business             Gliese 581
# 1        22    Male         Tourist      Economy         Alpha Centauri
# 2        62  Female  Businessperson       Luxury         Alpha Centauri
# 3        21  Female        Colonist      Economy          Lalande 21185
# 4        42    Male        Explorer       Luxury  Exotic Destination 10
# ...

# %%
print('Ukuran Data: ', dataFrame.shape)
# Out:
# Ukuran Data:  (547568, 18)

# %%
feature_names = dataFrame.columns[:-1]
target_names = 'Loyalty Program Member'

features = dataFrame[feature_names]
target = dataFrame[target_names]

print('Feature Names :', features)
print('Target Names :', target)
# Out:
# Feature Names :         Age  Gender      Occupation Travel Class            Destination  \
# 0        14  Female        Colonist     Business             Gliese 581
# 1        22    Male         Tourist      Economy         Alpha Centauri
# 2        62  Female  Businessperson       Luxury         Alpha Centauri
# 3        21  Female        Colonist      Economy          Lalande 21185
# 4        42    Male        Explorer       Luxury  Exotic Destination 10
# ...     ...     ...             ...          ...                    ...
# 547563   72    Male       Scientist      Economy       Zeta II Reticuli
# 547564   23    Male         Tourist     Business   Exotic Destination 7
# 547565    6  Female        Colonist     Business       Proxima Centauri
# 547566   21  Female           Other     Business         Alpha Centauri
# 547567   42    Male       Scientist      Economy       Zeta II Reticuli
#
#                  Star System  Distance to Destination (Light-Years)  \
# ...

# %%
from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()

dataFrame['Gender']   = label_encoder.fit_transform(dataFrame['Gender'])
dataFrame['Occupation']   = label_encoder.fit_transform(dataFrame['Occupation'])
dataFrame['Travel Class']   = label_encoder.fit_transform(dataFrame['Travel Class'])
dataFrame['Destination']   = label_encoder.fit_transform(dataFrame['Destination'])
dataFrame['Star System']   = label_encoder.fit_transform(dataFrame['Star System'])
dataFrame['Purpose of Travel']   = label_encoder.fit_transform(dataFrame['Purpose of Travel'])
dataFrame['Transportation Type']   = label_encoder.fit_transform(dataFrame['Transportation Type'])
dataFrame['Booking Date']   = label_encoder.fit_transform(dataFrame['Booking Date'])
dataFrame['Departure Date']   = label_encoder.fit_transform(dataFrame['Departure Date'])
dataFrame['Special Requests']   = label_encoder.fit_transform(dataFrame['Special Requests'])
dataFrame['Loyalty Program Member']   = label_encoder.fit_transform(dataFrame['Loyalty Program Member'])

dataFrame
# Out:
#         Age  Gender  Occupation  Travel Class  Destination  Star System  \
# 0        14       0           1             0           13        40376
# 1        22       1           5             1            0        71908
# 2        62       0           0             2            0         6943
# 3        21       0           1             1           15        73359
# 4        42       1           2             2            4        65879
# ...     ...     ...         ...           ...          ...          ...
# 547563   72       1           4             1           19       134818
# 547564   23       1           5             0           10       146889
# 547565    6       0           1             0           16        87320
# 547566   21       0           3             0            0        51598
# 547567   42       1           4             1           19        66152
#
#         Distance to Destination (Light-Years)  Duration of Stay (Earth Days)  \
# ...

# %%
X = dataFrame.drop('Loyalty Program Member', axis=1)
Y = dataFrame['Loyalty Program Member']

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.2)

# %%
print(x_train.shape)
print(x_test.shape)
# Out:
# (438054, 17)
# (109514, 17)

# %%
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(x_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
y_predict = knn.predict(x_test)

# %%
from sklearn import metrics
print('Accuracy Score of K-NN Model: ', metrics.accuracy_score(y_test, y_predict))
# Out:
# Accuracy Score of K-NN Model:  0.5128385411910806

# %%
sample = [[289453, 15663487, 618, 659, 1, 1, 42.0, 1, 125901.52, 2, 1.0, 0.0, 93081.91]]
predictions = knn.predict(sample)
# pred_species = [df.target_names[p] for p in preds]
print("Hasil Prediksi Sampel Data : ", predictions)
